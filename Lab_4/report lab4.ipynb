# %% [markdown]
# # Lab 4
# > variant 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
import random as rd

Variant = 12
rd.seed(Variant)

Numbers_of_problems = sorted([i+1 for i in rd.sample(range(14),3)])
Numbers_of_problems
# Out:
# [5, 8, 11]

# %%
res = 0
n = int(input())

for i in range(1, n + 1):
    if (i % 5 == 0 or i % 11 == 0):
        continue
    res += 1

print(res)
# Out:
# 3094
# 2251
