# %%
import random as rd
import pandas as pd
import math

Variant = 12
rd.seed(Variant)

set_operations = ['-','+','*','/']
set_operands = ['a', 'b', 'c']
count_operations = rd.randint(3,5)

expression = set_operands[rd.randint(0,len(set_operands)-1)]
for i in range(count_operations):
    current_operation = set_operations[rd.randint(0,len(set_operations)-1)]
    current_operand = set_operands[rd.randint(0,len(set_operands)-1)]
    expression = "(" + expression + current_operation + current_operand + ")"
expression
# Out:
# '((((b*a)/a)*b)*c)'

# %% [markdown]
# ## Screenshots of programm's work
#
# 1) ![image.png](data:image/png;base64,...)
#
# 2) ![image.png](data:image/png;base64,...)
# 3) ![image.png](data:image/png;base64,...)
#
# > Исполняемые файлы для ассемблера называются `a`, для C `с`
#
# > `fasm3` это моя функция для оболочки терминала [fish](https://fishshell.com/). Там сначала компилируется файл .asm, происходит линковка, удаляется файл .o, и выдаются права на исполнение

# %% [markdown]
# Исходники с кодом находятся в репозитории, там же, где и исполняемые файлы под 32битную систему
