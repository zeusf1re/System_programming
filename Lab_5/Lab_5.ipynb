# %% [markdown]
# #Lab 5
# >variant 12

# %%
import random as rd

Variant = 12
rd.seed(Variant)

Numbers_of_problems = [i+1 for i in rd.sample(range(11),2)]
Numbers_of_problems
# Out:
# [8, 5]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
